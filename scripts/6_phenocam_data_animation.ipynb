# %%
import decid_package.image_animation as phenocam

image_dir = "../data/Phenocams"  # or full path like "/Users/rune/project/images"
start_time = "2024-10-22 12:00:00"
end_time = "2024-10-30 12:30:00"
interval = 100  # milliseconds between frames
export_path = "../outputs/phenocam_leaf_flush2.mp4"

phenocam.run_phenocam_animation(image_dir, start_time, end_time, interval, export_path)
# Out:
# Found 130 images between 2024-10-22 12:00:00 and 2024-10-30 12:30:00
# 🎞️ Animation saved to 'c:\Users\decle\OneDrive - UGent\_Vakantiejob_Rune_Declercq\outputs\phenocam_leaf_flush2.mp4'
